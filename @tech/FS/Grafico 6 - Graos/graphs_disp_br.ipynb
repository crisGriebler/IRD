# %% [markdown]
# ### Link of the Matplotlib docs
# ##### https://docs.kanaries.net/pt/topics/Matplotlib/matplotlib-multiple-plots-on-same-figure

# %%
#importing necessary packages

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import datetime
import imageio
import os

# %%
#função para tratar campo data
def parser(x):
    return pd.datetime.strptime('190'+x, '%Y-%m')

#Agora vamos importar nosso arquivo 
df_alcool = pd.read_excel('../Grafico 5 - Proteina/db_br30.xlsx', sheet_name='Sheet1')
print(df_alcool.head(10))
# Out:
#    date  animal_protein  ethanol_liter
# 0  2014          260.80          70939
# 1  2015          258.90         141617
# 2  2016          257.39         200740
# 3  2017          255.06         412770
# 4  2018          259.33         720236
# 5  2019          266.04        1330163
# 6  2020          267.16        2430153
# 7  2021          264.94        3296386
# 8  2022          291.40        4141401
# 9  2023          293.79        4986399

# %%
#df_alcool.drop(['animal_protein'], axis = 1,inplace=True)

# %%
df_alcool=df_alcool[3:]
len(df_alcool)
# Out:
# 14

# %%
#função para tratar campo data
def parser(x):
    return pd.datetime.strptime('190'+x, '%Y-%m')

#Agora vamos importar nosso arquivo 
df_milho = pd.read_excel('dbmilho_br30.xls', sheet_name='Planilha1')
len(df_milho)
# Out:
# 54

# %%
df_milho=df_milho[40:]
len(df_milho)
# Out:
# 14

# %%
#função para tratar campo data
def parser(x):
    return pd.datetime.strptime('190'+x, '%Y-%m')

#Agora vamos importar nosso arquivo 
df_soja = pd.read_excel('dbsoja_br30.xls', sheet_name='Planilha1')
df_soja.tail(10)
# Out:
#     date     producao  produtividade        area
# 44  2021  139385.3000      3526.0000  39531.2000
# 45  2022  125549.8000      3026.0000  41492.0000
# 46  2023  154609.5000      3507.0000  44080.1000
# 47  2024  146878.4794      3437.2277  46172.6751
# 48  2025  156542.0370      3459.6474  47658.2998
# 49  2026  162440.5723      3482.0671  49143.9245
# 50  2027  168339.1077      3504.4868  50629.5493
# 51  2028  174237.6431      3526.9065  52115.1740
# 52  2029  180136.1785      3549.3262  53600.7987
# 53  2030  186034.7139      3571.7459  55086.4234

# %%
df_soja=df_soja[40:]
len(df_soja)
# Out:
# 14

# %%
# Definindo as variaveis com as colunas do df
x = df_soja['date']
y1 = df_alcool['ethanol_liter']
y2 = df_soja['producao']
y3 = df_milho['producao']

# Cria uma nova Figura e Axes
fig, ax1 = plt.subplots()
 
# Cria um segundo Axes que compartilha o mesmo eixo x
ax2 = ax1.twinx()
#ax3 = ax2.twinx()

 
# Plotar dados em cada Axes
ax1.plot(x, y1, 'k-', label='litros de etanol', marker='.', linestyle='dashed')
ax2.plot(x, y2, 'k-', label='soja', marker='.', linestyle='solid')   #marker='o'
ax2.plot(x, y3, 'k-', label='milho', marker='.', linestyle='dotted')   #marker='o'



# Definir rótulos dos eixos y
ax1.set_ylabel('Produção de etanol mil (milhões de litros', color='k', )
ax2.set_ylabel('Produção de grãos (toneladas)', color='r')
#ax3.set_ylabel('', color='b')

# Incluir legenda
ax1.legend(loc='center right')
ax2.legend(loc='best')
#ax3.legend(loc='best')

 
# Mostrar o gráfico
plt.show()
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_26428\1217220924.py:16: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(x, y1, 'k-', label='litro de etanol', marker='.', linestyle='dashed')
# C:\Users\crist\AppData\Local\Temp\ipykernel_26428\1217220924.py:17: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax2.plot(x, y2, 'r-', label='soja', marker='.', linestyle='solid')   #marker='o'
# C:\Users\crist\AppData\Local\Temp\ipykernel_26428\1217220924.py:18: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax2.plot(x, y3, 'b-', label='milho', marker='.', linestyle='dotted')   #marker='o'

# %% [markdown]
# #### AVALIANDO A DISPONIBILIDADE

# %%
#função para tratar campo data
#def parser(x):
#    return pd.datetime.strptime('190'+x, '%Y-%m')

#Agora vamos importar nosso arquivo 
#df_alcool = pd.read_excel('../Grafico 5 - Proteina/db_br30.xlsx', sheet_name='Sheet1')
#print(df_alcool.head(10))

# %%
#df_alcool.drop(['ethanol_liter'], axis = 1,inplace=True)

# %%
# Definindo as variaveis com as colunas do df
x = df_soja['date']
y1 = df_alcool['ethanol_liter']
y2 = df_soja['produtividade']
y3 = df_milho['produtividade']

# Cria uma nova Figura e Axes
fig, ax1 = plt.subplots()
 
# Cria um segundo Axes que compartilha o mesmo eixo x
ax2 = ax1.twinx()
#ax3 = ax2.twinx()

 
# Plotar dados em cada Axes
ax1.plot(x, y1, 'k-', label='litros de etanol', marker='o', linestyle='solid')
ax2.plot(x, y2, 'k-', label='soja', marker='.', linestyle='dashed')   #marker='o'
ax2.plot(x, y3, 'k-', label='milho', marker='.', linestyle='dotted')   #marker='o'


# Definir rótulos dos eixos y
ax1.set_ylabel('Produção de etanol mil (milhões de litros)', color='k', )
ax2.set_ylabel('Produtividade de graos (kg/hectares)', color='k')
#ax3.set_ylabel('', color='b')

# Incluir legenda
ax2.legend(loc='center right')
#ax2.legend(loc='best')
#ax3.legend(loc='best')

 
# Mostrar o gráfico
plt.show()
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_26428\455936284.py:16: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(x, y1, 'k-', label='litros de etanol', marker='o', linestyle='solid')
# C:\Users\crist\AppData\Local\Temp\ipykernel_26428\455936284.py:17: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax2.plot(x, y2, 'k-', label='soja', marker='.', linestyle='dashed')   #marker='o'
# C:\Users\crist\AppData\Local\Temp\ipykernel_26428\455936284.py:18: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax2.plot(x, y3, 'k-', label='milho', marker='.', linestyle='dotted')   #marker='o'
