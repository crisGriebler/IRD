# %% [markdown]
# ### Link of the Matplotlib docs
# ##### https://docs.kanaries.net/pt/topics/Matplotlib/matplotlib-multiple-plots-on-same-figure

# %%
#importing necessary packages

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import datetime
import imageio
import os

# %%
#função para tratar campo data
def parser(x):
    return pd.datetime.strptime('190'+x, '%Y-%m')

#Agora vamos importar nosso arquivo 
df_alcool = pd.read_excel('../Grafico 5 - Proteina/db_br30.xlsx', sheet_name='Sheet1')
print(df_alcool.head(10))
# Out:
#    date  animal_protein  ethanol_liter
# 0  2014          260.80          70939
# 1  2015          258.90         141617
# 2  2016          257.39         200740
# 3  2017          255.06         412770
# 4  2018          259.33         720236
# 5  2019          266.04        1330163
# 6  2020          267.16        2430153
# 7  2021          264.94        3296386
# 8  2022          291.40        4141401
# 9  2023          293.79        4986399

# %%
#df_alcool.drop(['animal_protein'], axis = 1,inplace=True)

# %%
df_alcool=df_alcool[3:]
len(df_alcool)
# Out:
# 14

# %%
#função para tratar campo data
def parser(x):
    return pd.datetime.strptime('190'+x, '%Y-%m')

#Agora vamos importar nosso arquivo 
df = pd.read_excel('dbmilho_br30.xls', sheet_name='Planilha1')
print(df.tail(10))
# Out:
#     date   producao  disponibilidade   tipo
# 18  2029  154564400         21314260   soja
# 19  2030  156766500         21576600   soja
# 20  2023  104695131         42792190  milho
# 21  2024   88976312         44649900  milho
# 22  2025  102534801         46507600  milho
# 23  2026  105399327         48365310  milho
# 24  2027   89680508         50223020  milho
# 25  2028  103238997         52080730  milho
# 26  2029  106103523         53938440  milho
# 27  2030   90384704         55796150  milho

# %%
df_soja = df[df['tipo']=='soja']
df_soja.drop(['producao', 'tipo'], axis = 1,inplace=True)
df_soja.tail(10)
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_26428\3492670223.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_soja.drop(['producao', 'tipo'], axis = 1,inplace=True)
#     date  disponibilidade
# 4   2021         18984300
# 5   2022         19477880
# 12  2023         19740220
# 13  2024         20002560
# 14  2025         20264900
# 15  2026         20527240
# 16  2027         20789580
# 17  2028         21051920
# 18  2029         21314260
# 19  2030         21576600

# %%
df_milho = df[df['tipo']=='milho']
df_milho.drop(['producao', 'tipo'], axis = 1,inplace=True)
df_milho.tail(10)
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_26428\3934499764.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_milho.drop(['producao', 'tipo'], axis = 1,inplace=True)
#     date  disponibilidade
# 10  2021         39126269
# 11  2022         40934480
# 20  2023         42792190
# 21  2024         44649900
# 22  2025         46507600
# 23  2026         48365310
# 24  2027         50223020
# 25  2028         52080730
# 26  2029         53938440
# 27  2030         55796150

# %%
#len(df_soja['date'])
len(df_alcool['ethanol_liter'])
#df_soja['disponibilidade']
# Out:
# 14

# %%
# Definindo as variaveis com as colunas do df
x = df_soja['date']
y1 = df_alcool['ethanol_liter']
y2 = df_soja['disponibilidade']
y3 = df_milho['disponibilidade']

# Cria uma nova Figura e Axes
fig, ax1 = plt.subplots()
 
# Cria um segundo Axes que compartilha o mesmo eixo x
ax2 = ax1.twinx()
#ax3 = ax2.twinx()

 
# Plotar dados em cada Axes
ax1.plot(x, y1, 'k-', label='litro de etanol', marker='.', linestyle='dashed')
ax2.plot(x, y2, 'r-', label='soja', marker='.', linestyle='solid')   #marker='o'
ax2.plot(x, y3, 'b-', label='milho', marker='.', linestyle='dotted')   #marker='o'



# Definir rótulos dos eixos y
ax1.set_ylabel('Producação de litros de etanol(milhões de litros)', color='k', )
ax2.set_ylabel('Disponibilidade de graos (hectares)', color='r')
#ax3.set_ylabel('', color='b')

# Incluir legenda
ax1.legend(loc='center right')
ax2.legend(loc='best')
#ax3.legend(loc='best')

 
# Mostrar o gráfico
plt.show()
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_26428\255843416.py:16: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(x, y1, 'k-', label='litro de etanol', marker='.', linestyle='dashed')
# C:\Users\crist\AppData\Local\Temp\ipykernel_26428\255843416.py:17: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax2.plot(x, y2, 'r-', label='soja', marker='.', linestyle='solid')   #marker='o'
# C:\Users\crist\AppData\Local\Temp\ipykernel_26428\255843416.py:18: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax2.plot(x, y3, 'b-', label='milho', marker='.', linestyle='dotted')   #marker='o'

# %% [markdown]
# #### AVALIANDO A DISPONIBILIDADE

# %%
#função para tratar campo data
#def parser(x):
#    return pd.datetime.strptime('190'+x, '%Y-%m')

#Agora vamos importar nosso arquivo 
#df_alcool = pd.read_excel('../Grafico 5 - Proteina/db_br30.xlsx', sheet_name='Sheet1')
#print(df_alcool.head(10))

# %%
#df_alcool.drop(['ethanol_liter'], axis = 1,inplace=True)

# %%
# Definindo as variaveis com as colunas do df
x = df_soja['date']
y1 = df_alcool['animal_protein']
y2 = df_soja['disponibilidade']
y3 = df_milho['disponibilidade']

# Cria uma nova Figura e Axes
fig, ax1 = plt.subplots()
 
# Cria um segundo Axes que compartilha o mesmo eixo x
ax2 = ax1.twinx()
#ax3 = ax2.twinx()

 
# Plotar dados em cada Axes
ax1.plot(x, y1, 'k-', label='proteina', marker='.', linestyle='dashed')
ax2.plot(x, y2, 'k-', label='soja', marker='o', linestyle='solid')   #marker='o'
ax2.plot(x, y3, 'k-', label='milho', marker='.', linestyle='dotted')   #marker='o'



# Definir rótulos dos eixos y
ax1.set_ylabel('Consumo per capita de proteínas (kg/capita/ano)', color='k', )
ax2.set_ylabel('Disponibilidade de graos (hectares)', color='r')
#ax3.set_ylabel('', color='b')

# Incluir legenda
ax2.legend(loc='center right')
#ax2.legend(loc='best')
#ax3.legend(loc='best')

 
# Mostrar o gráfico
plt.show()
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_26428\2642982900.py:16: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(x, y1, 'k-', label='proteina', marker='.', linestyle='dashed')
# C:\Users\crist\AppData\Local\Temp\ipykernel_26428\2642982900.py:17: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax2.plot(x, y2, 'k-', label='soja', marker='o', linestyle='solid')   #marker='o'
# C:\Users\crist\AppData\Local\Temp\ipykernel_26428\2642982900.py:18: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax2.plot(x, y3, 'k-', label='milho', marker='.', linestyle='dotted')   #marker='o'
