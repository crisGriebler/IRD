# %% [markdown]
# ## Gráficos de emissão de gases do efeito estufa(GEE) dos combustiveis (Estudo até 2033)

# %% [markdown]
# ### Link of the Matplotlib docs
# ##### https://docs.kanaries.net/pt/topics/Matplotlib/matplotlib-multiple-plots-on-same-figure

# %%
#importing necessary packages

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import datetime
import imageio
import os

# %%
#função para tratar campo data
def parser(x):
    return pd.datetime.strptime('190'+x, '%Y-%m')

#Agora vamos importar nosso arquivo de PIB brasileiro
df = pd.read_csv('emissao.csv')
print(df.head(10))
# Out:
#    data  etanol_milho   etanol_cana      gasolina  etanol_total        diesel
# 0  2023  6.000000e+06  2.401583e+07  3.173224e+07  3.001583e+07  5.658616e+07
# 1  2024  7.200000e+06  2.520747e+07  3.183165e+07  3.240747e+07  5.669966e+07
# 2  2025  8.280000e+06  2.667011e+07  3.041789e+07  3.495011e+07  5.937714e+07
# 3  2026  9.108000e+06  3.034306e+07  2.739921e+07  3.945106e+07  6.000750e+07
# 4  2027  9.563400e+06  3.255931e+07  2.605892e+07  4.212271e+07  6.041412e+07
# 5  2028  1.004157e+07  3.449424e+07  2.495878e+07  4.453581e+07  6.095517e+07
# 6  2029  1.054365e+07  3.746790e+07  2.331447e+07  4.801155e+07  6.220766e+07
# 7  2030  1.107083e+07  3.794937e+07  2.331369e+07  4.902020e+07  6.268653e+07
# 8  2031  1.162437e+07  3.904077e+07  2.301191e+07  5.066514e+07  6.390738e+07
# 9  2032  1.220559e+07  3.908334e+07  2.345942e+07  5.128893e+07  6.512092e+07

# %%
df = df.round(2)
print(df.head(10))
# Out:
#    data  etanol_milho  etanol_cana     gasolina  etanol_total       diesel
# 0  2023    6000000.00  24015826.23  31732239.16   30015826.23  56586159.92
# 1  2024    7200000.00  25207465.67  31831646.15   32407465.67  56699657.03
# 2  2025    8280000.00  26670109.87  30417891.00   34950109.87  59377142.47
# 3  2026    9108000.00  30343055.87  27399214.81   39451055.87  60007499.33
# 4  2027    9563400.00  32559313.88  26058916.24   42122713.88  60414121.04
# 5  2028   10041570.00  34494241.18  24958776.85   44535811.18  60955165.74
# 6  2029   10543648.50  37467898.95  23314473.40   48011547.45  62207659.15
# 7  2030   11070831.00  37949365.80  23313691.21   49020196.72  62686530.02
# 8  2031   11624372.47  39040768.25  23011905.95   50665140.72  63907379.45
# 9  2032   12205591.09  39083336.18  23459420.15   51288927.27  65120915.70

# %%
#df.drop(['value'], axis = 1,inplace=True)

# %%
#df1=df.set_index('data',inplace=True)

# %%
#df1=df.sort_index(axis=0)
#print(df1.tail(10))

# %%
# Definindo as variaveis com as colunas do df
x = df['data']
y1 = df['etanol_cana']
y2 = df['etanol_milho']
y3 = df['etanol_total']

# Cria uma nova Figura e Axes
fig, ax1 = plt.subplots()
 
# Cria um segundo Axes que compartilha o mesmo eixo x
#ax2 = ax1.twinx()
#ax3 = ax2.twinx()

# Plotar dados em cada Axes
ax1.plot(x, y3, 'k-', label='etanol-total', marker='o', linestyle='solid')   #marker='o'
ax1.plot(x, y1, 'k-', label='etanol-cana', marker='x', linestyle='dotted')
ax1.plot(x, y2, 'k-', label='etanol-milho', marker='.', linestyle='dashed')   #marker='o'

# Definir rótulos dos eixos y
ax1.set_ylabel('Produção de gases (gCO2eq/MJ)', color='k' )
#ax2.set_ylabel('etanol-milho', color='k')
#ax3.set_ylabel('etanol-total', color='k')

# Incluir legenda
ax1.legend(loc='upper left')
#ax2.legend(loc='center left')
 
# Mostrar o gráfico
plt.show()
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_12932\290032942.py:15: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(x, y3, 'k-', label='etanol-total', marker='o', linestyle='solid')   #marker='o'
# C:\Users\crist\AppData\Local\Temp\ipykernel_12932\290032942.py:16: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(x, y1, 'k-', label='etanol-cana', marker='x', linestyle='dotted')
# C:\Users\crist\AppData\Local\Temp\ipykernel_12932\290032942.py:17: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(x, y2, 'k-', label='etanol-milho', marker='.', linestyle='dashed')   #marker='o'

# %%
# Definindo as variaveis com as colunas do df
x = df['data']
y1 = df['etanol_total']
y2 = df['gasolina']
y3 = df['diesel']

# Cria uma nova Figura e Axes
fig, ax1 = plt.subplots()
 
# Cria um segundo Axes que compartilha o mesmo eixo x
#ax2 = ax1.twinx()
#ax3 = ax2.twinx()

# Plotar dados em cada Axes
ax1.plot(x, y1, 'k-', label='etanol', marker='x', linestyle='dashed')
ax1.plot(x, y2, 'k-', label='gasolina', marker='o', linestyle='solid')   #marker='o'
ax1.plot(x, y3, 'k-', label='diesel', marker='.', linestyle='dotted')   #marker='o'

# Definir rótulos dos eixos y
ax1.set_ylabel('Produção de gases (gCO2eq/MJ)', color='k' )
#ax2.set_ylabel('etanol-milho', color='k')
#ax3.set_ylabel('etanol-total', color='k')

# Incluir legenda
ax1.legend(loc='center left')
#ax2.legend(loc='center left')
 
# Mostrar o gráfico
plt.show()
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_12932\3182436784.py:15: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(x, y1, 'k-', label='etanol', marker='x', linestyle='dashed')
# C:\Users\crist\AppData\Local\Temp\ipykernel_12932\3182436784.py:16: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(x, y2, 'k-', label='gasolina', marker='o', linestyle='solid')   #marker='o'
# C:\Users\crist\AppData\Local\Temp\ipykernel_12932\3182436784.py:17: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(x, y3, 'k-', label='diesel', marker='.', linestyle='dotted')   #marker='o'

# %%
# Definindo as variaveis com as colunas do df
x = df['data']
y1 = df['gasolina']
y2 = df['etanol_milho']
y3 = df['etanol_cana']

# Cria uma nova Figura e Axes (give you freedom to plot different axes in the same fig)
fig, ax1 = plt.subplots()
 
# Cria um segundo Axes que compartilha o mesmo eixo x
ax2 = ax1.twinx()
#ax3 = ax1.twinx()

# Plotar dados em cada Axes
ax1.plot(x, y1, 'k-', label='gasolina', marker='o', linestyle='solid')
ax2.plot(x, y2, 'k', label='etanol milho', marker='.', linestyle='dashed')   #marker='o'
ax2.plot(x, y3, 'k-', label='etanol cana', marker='x', linestyle='dotted')   #marker='o'

# Definir rótulos dos eixos y
ax1.set_ylabel('Produção de gases (gCO2eq/MJ)', color='k' )
#ax2.set_ylabel('etanol-milho', color='k')
#ax3.set_ylabel('etanol-total', color='k')

# Incluir legenda
ax2.legend(loc='center right')
#ax1.legend(loc='center right')
 
# Mostrar o gráfico
plt.show()
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_12932\2238868145.py:15: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(x, y1, 'k-', label='gasolina', marker='o', linestyle='solid')
# C:\Users\crist\AppData\Local\Temp\ipykernel_12932\2238868145.py:17: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax2.plot(x, y3, 'k-', label='etanol cana', marker='x', linestyle='dotted')   #marker='o'

# %%
# Definindo as variaveis com as colunas do df
x = df['data']
y1 = df['gasolina']
y2 = df['etanol_milho']
y3 = df['etanol_cana']

# Cria uma nova Figura e Axes (give you freedom to plot different axes in the same fig)
fig, ax1 = plt.subplots()
 
# Cria um segundo Axes que compartilha o mesmo eixo x
#ax2 = ax1.twinx()
#ax3 = ax1.twinx()

# Plotar dados em cada Axes
ax1.plot(x, y1, 'k-', label='gasolina', marker='o', linestyle='solid')
ax1.plot(x, y2, 'k', label='etanol milho', marker='.', linestyle='dashed')   #marker='o'
ax1.plot(x, y3, 'k-', label='etanol cana', marker='x', linestyle='dotted')   #marker='o'

# Definir rótulos dos eixos y
ax1.set_ylabel('Produção de gases (gCO2eq/MJ)', color='k' )
#ax2.set_ylabel('etanol-milho', color='k')
#ax3.set_ylabel('etanol-total', color='k')

# Incluir legenda
ax1.legend(loc='upper left')
#ax1.legend(loc='center right')
 
# Mostrar o gráfico
plt.show()
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_12932\522657220.py:15: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(x, y1, 'k-', label='gasolina', marker='o', linestyle='solid')
# C:\Users\crist\AppData\Local\Temp\ipykernel_12932\522657220.py:17: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(x, y3, 'k-', label='etanol cana', marker='x', linestyle='dotted')   #marker='o'

# %%
# Definindo as variaveis com as colunas do df
x = df['data']
y1 = df['gasolina']
y2 = df['etanol_milho']
y3 = df['diesel']

# Cria uma nova Figura e Axes (give you freedom to plot different axes in the same fig)
fig, ax1 = plt.subplots()
 
# Cria um segundo Axes que compartilha o mesmo eixo x
#ax2 = ax1.twinx()
#ax3 = ax1.twinx()

# Plotar dados em cada Axes
ax1.plot(x, y1, 'k-', label='gasolina', marker='o', linestyle='solid')
ax1.plot(x, y2, 'k', label='etanol milho', marker='x', linestyle='dotted')   #marker='o'
ax1.plot(x, y3, 'k-', label='diesel', marker='.', linestyle='dashed')   #marker='o'

# Definir rótulos dos eixos y
ax1.set_ylabel('Produção de gases (gCO2eq/MJ)', color='k' )
#ax2.set_ylabel('etanol-milho', color='k')
#ax3.set_ylabel('etanol-total', color='k')

# Incluir legenda
ax1.legend(loc='center right')
#ax1.legend(loc='center right')
 
# Mostrar o gráfico
plt.show()
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_12932\353860980.py:15: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(x, y1, 'k-', label='gasolina', marker='o', linestyle='solid')
# C:\Users\crist\AppData\Local\Temp\ipykernel_12932\353860980.py:17: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(x, y3, 'k-', label='diesel', marker='.', linestyle='dashed')   #marker='o'
