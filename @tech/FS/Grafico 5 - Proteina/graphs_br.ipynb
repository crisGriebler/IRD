# %% [markdown]
# ### Link of the Matplotlib docs
# ##### https://docs.kanaries.net/pt/topics/Matplotlib/matplotlib-multiple-plots-on-same-figure

# %%
#importing necessary packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import datetime
import imageio
import os

# %%
#função para tratar campo data
def parser(x):
    return pd.datetime.strptime('190'+x, '%Y-%m')

#Agora vamos importar nosso arquivo 
df = pd.read_excel('db_br30.xlsx', sheet_name='Sheet1')
print(df.head(10))
# Out:
#    date  animal_protein  ethanol_liter
# 0  2014          260.80          70939
# 1  2015          258.90         141617
# 2  2016          257.39         200740
# 3  2017          255.06         412770
# 4  2018          259.33         720236
# 5  2019          266.04        1330163
# 6  2020          267.16        2430153
# 7  2021          264.94        3296386
# 8  2022          291.40        4141401
# 9  2023          293.79        4986399

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            17 non-null     int64
#  1   animal_protein  17 non-null     float64
#  2   ethanol_liter   17 non-null     int64
# dtypes: float64(1), int64(2)
# memory usage: 536.0 bytes

# %%
# Definindo as variaveis com as colunas do df
x = df['date']
y1 = df['animal_protein']
y2 = df['ethanol_liter']

# Cria uma nova Figura e Axes
fig, ax1 = plt.subplots()
 
# Cria um segundo Axes que compartilha o mesmo eixo x
ax2 = ax1.twinx()
 
# Plotar dados em cada Axes
ax1.plot(x, y1, 'k-', label='proteina', marker='.', linestyle='dashed')
ax1.plot(x, y2, 'r-', label='etanol', marker='.', linestyle='solid')   #marker='o'
 
# Definir rótulos dos eixos y
ax2.set_ylabel('Produção de etanol (milhões de litros)', color='r')
ax1.set_ylabel('Produção de etanol (milhões de litros)', color='r')


ax1.legend(loc='upper left')
ax2.legend(loc='lower right')
 
# Mostrar o gráfico
plt.show()
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_16364\1642851076.py:13: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(x, y1, 'k-', label='proteina', marker='.', linestyle='dashed')
# C:\Users\crist\AppData\Local\Temp\ipykernel_16364\1642851076.py:14: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax2.plot(x, y2, 'r-', label='etanol', marker='.', linestyle='solid')   #marker='o'
