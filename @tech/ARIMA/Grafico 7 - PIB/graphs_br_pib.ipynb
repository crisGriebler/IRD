# %% [markdown]
# ### Link of the Matplotlib docs
# ##### https://docs.kanaries.net/pt/topics/Matplotlib/matplotlib-multiple-plots-on-same-figure

# %%
#importing necessary packages

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import datetime
import imageio
import os

# %%
#função para tratar campo data
def parser(x):
    return pd.datetime.strptime('190'+x, '%Y-%m')

#Agora vamos importar nosso arquivo de PIB brasileiro
df = pd.read_csv('../../FS/Grafico 7 - PIB/PIB.csv')
print(df.tail(10))
# Out:
#         PIB  Date PIB.tri
# 7   2355982  2021    2,36
# 8   2641485  2022    2,64
# 9   2779095  2023    2,78
# 10  2865766  2024    2,87
# 11  2952437  2025    2,95
# 12  3039108  2026    3,04
# 13  3125779  2027    3,13
# 14  3212450  2028    3,21
# 15  3299121  2029    3,30
# 16  3385791  2030    3,39

# %%
#função para tratar campo data
def parser(x):
    return pd.datetime.strptime('190'+x, '%Y-%m')

#Agora vamos importar nosso arquivo 
df1 = pd.read_excel('../../FS/Grafico 5 - Proteina/db_br30.xlsx', sheet_name='Sheet1')
print(df1.head(10))
# Out:
#    date  animal_protein  ethanol_liter
# 0  2014          260.80          70939
# 1  2015          258.90         141617
# 2  2016          257.39         200740
# 3  2017          255.06         412770
# 4  2018          259.33         720236
# 5  2019          266.04        1330163
# 6  2020          267.16        2430153
# 7  2021          264.94        3296386
# 8  2022          291.40        4141401
# 9  2023          293.79        4986399

# %%
#df1.drop(['value'], axis = 1,inplace=True)

# %%
df1.set_index('date',inplace=True)

# %%
df1=df1.sort_index(axis=0)
print(df1.tail(10))
# Out:
#       animal_protein  ethanol_liter
# date
# 2021          264.94        3296386
# 2022          291.40        4141401
# 2023          293.79        4986399
# 2024          296.65        5831395
# 2025          299.50        6676391
# 2026          302.35        7521387
# 2027          305.20        8366383
# 2028          308.06        9211379
# 2029          310.91       10056370
# 2030          313.76       10901370

# %%
# Definindo as variaveis com as colunas do df
x = df['Date']
y1 = df1['ethanol_liter']
y2 = df['PIB']
#y3 = df_milho['producao']

# Cria uma nova Figura e Axes
fig, ax1 = plt.subplots()
 
# Cria um segundo Axes que compartilha o mesmo eixo x
ax2 = ax1.twinx()
#ax3 = ax2.twinx()

# Plotar dados em cada Axes
ax1.plot(x, y1, 'k-', label='etanol', marker='o', linestyle='solid')
ax2.plot(x, y2, 'k-', label='PIB', marker='.', linestyle='dashed')   #marker='o'
#ax3.plot(x, y3, 'b-', label='milho', marker='.', linestyle='dotted')   #marker='o'

# Definir rótulos dos eixos y
ax1.set_ylabel('Producação de litros de etanol', color='k', )
ax2.set_ylabel('PIB (R$)', color='k')
#ax3.set_ylabel('', color='b')

# Incluir legenda
ax1.legend(loc='upper left')
ax2.legend(loc='center left')
 
# Mostrar o gráfico
plt.show()
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_20736\1278154566.py:15: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(x, y1, 'k-', label='etanol', marker='o', linestyle='solid')
# C:\Users\crist\AppData\Local\Temp\ipykernel_20736\1278154566.py:16: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax2.plot(x, y2, 'k-', label='PIB', marker='.', linestyle='dashed')   #marker='o'

# %%
# Definindo as variaveis com as colunas do df
x = df['Date']
y1 = df1['animal_protein']
y2 = df['PIB']
#y3 = df_milho['producao']

# Cria uma nova Figura e Axes
fig, ax1 = plt.subplots()
 
# Cria um segundo Axes que compartilha o mesmo eixo x
ax2 = ax1.twinx()
#ax3 = ax2.twinx()

# Plotar dados em cada Axes
ax1.plot(x, y1, 'k-', label='Consumo de proteina animal (capita/kg/ano)', marker='o', linestyle='solid')
ax2.plot(x, y2, 'k-', label='PIB', marker='.', linestyle='dashed')   #marker='o'
#ax3.plot(x, y3, 'b-', label='milho', marker='.', linestyle='dotted')   #marker='o'

# Definir rótulos dos eixos y
ax1.set_ylabel('Producação de litros de etanol', color='k', )
ax2.set_ylabel('PIB (R$)', color='k')
#ax3.set_ylabel('', color='b')

# Incluir legenda
ax1.legend(loc='upper left')
ax2.legend(loc='center left')
 
# Mostrar o gráfico
plt.show()
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_20736\1503761328.py:15: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(x, y1, 'k-', label='Consumo de proteina animal (capita/kg/ano)', marker='o', linestyle='solid')
# C:\Users\crist\AppData\Local\Temp\ipykernel_20736\1503761328.py:16: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax2.plot(x, y2, 'k-', label='PIB', marker='.', linestyle='dashed')   #marker='o'
