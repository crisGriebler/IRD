# %% [markdown]
# ### Link of the Matplotlib docs
# ##### https://docs.kanaries.net/pt/topics/Matplotlib/matplotlib-multiple-plots-on-same-figure

# %%
#importing necessary packages

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import datetime
import imageio
import os

# %%
#função para tratar campo data
def parser(x):
    return pd.datetime.strptime('190'+x, '%Y-%m')

#Agora vamos importar nosso arquivo 
df = pd.read_excel('PIB_br.xls', sheet_name='Planilha1')
print(df.head(10))
# Out:
#    date   etanol         PIB
# 0  2017   412770  2063514.69
# 1  2018   720236  1916933.71
# 2  2019  1330163  1881458.56
# 3  2020  2430153  1448565.67
# 4  2021  3296386  1608981.30
# 5  2022  4141401  1872790.27

# %%
#df_soja = df[df['tipo']=='soja']
#df.drop(['disponibilidade', 'tipo'], axis = 1,inplace=True)
#df.head(10)

# %%
df_milho = df[df['tipo']=='milho']
df_milho.drop(['disponibilidade', 'tipo'], axis = 1,inplace=True)
df_milho.head(10)
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_22588\3980232509.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_milho.drop(['disponibilidade', 'tipo'], axis = 1,inplace=True)
#     date  producao
# 6   2017  17427206
# 7   2018  16126368
# 8   2019  17515920
# 9   2020  18258981
# 10  2021  18984300
# 19  2022  20060550
# 20  2023  21087880
# 21  2024  22115220
# 22  2025  23142550
# 23  2026  24169880

# %%
# Definindo as variaveis com as colunas do df
x = df_soja['date']
y1 = df_alcool['liter']
y2 = df_soja['producao']
y3 = df_milho['producao']

# Cria uma nova Figura e Axes
fig, ax1 = plt.subplots()
 
# Cria um segundo Axes que compartilha o mesmo eixo x
ax2 = ax1.twinx()
ax3 = ax2.twinx()

 
# Plotar dados em cada Axes
ax1.plot(x, y1, 'k-', label='soja', marker='.', linestyle='dashed')
ax2.plot(x, y2, 'r-', label='liter', marker='.', linestyle='solid')   #marker='o'
ax3.plot(x, y3, 'b-', label='milho', marker='.', linestyle='dotted')   #marker='o'



# Definir rótulos dos eixos y
ax1.set_ylabel('Producação de litros de etanol', color='k', )
ax2.set_ylabel('Produção de grãos', color='r')
ax3.set_ylabel('', color='b')

# Incluir legenda
ax1.legend(loc='best')
ax2.legend(loc='best')
ax3.legend(loc='best')

 
# Mostrar o gráfico
plt.show()
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_22588\103167524.py:16: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(x, y1, 'k-', label='soja', marker='.', linestyle='dashed')
# C:\Users\crist\AppData\Local\Temp\ipykernel_22588\103167524.py:17: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax2.plot(x, y2, 'r-', label='liter', marker='.', linestyle='solid')   #marker='o'
# C:\Users\crist\AppData\Local\Temp\ipykernel_22588\103167524.py:18: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax3.plot(x, y3, 'b-', label='milho', marker='.', linestyle='dotted')   #marker='o'
