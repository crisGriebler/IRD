# %% [markdown]
# ### Link of the Matplotlib docs
# ##### https://docs.kanaries.net/pt/topics/Matplotlib/matplotlib-multiple-plots-on-same-figure

# %%
#importing necessary packages

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import datetime
import imageio
import os

# %%
#função para tratar campo data
def parser(x):
    return pd.datetime.strptime('190'+x, '%Y-%m')

#Agora vamos importar nosso arquivo 
df_alcool = pd.read_excel('../Grafico 5 - Proteina/db_br30.xlsx', sheet_name='Sheet1')
print(df_alcool.head(10))
# Out:
#    date   value    liter
# 0  2017  255.06   412770
# 1  2018  259.33   720236
# 2  2019  266.04  1330163
# 3  2020  267.16  2430153
# 4  2021  264.94  3296386
# 5  2022  291.40  4141401
# 6  2023  293.79  4986399
# 7  2024  296.65  5831395
# 8  2025  299.50  6676391
# 9  2026  302.35  7521387

# %%
df_alcool.drop(['value'], axis = 1,inplace=True)

# %%
#função para tratar campo data
def parser(x):
    return pd.datetime.strptime('190'+x, '%Y-%m')

#Agora vamos importar nosso arquivo 
df = pd.read_excel('dbgraos_br30.xls', sheet_name='Planilha1')
print(df.head(10))
# Out:
#    date   producao  disponibilidade   tipo
# 0  2017  114732101         17427206   soja
# 1  2018  117912450         16126368   soja
# 2  2019  114316829         17515920   soja
# 3  2020  121820949         18258981   soja
# 4  2021  134799179         18984300   soja
# 5  2022  139149400         19477880   soja
# 6  2017   97910658         33959879  milho
# 7  2018   82366531         34777936  milho
# 8  2019  101126409         35895207  milho
# 9  2020  103990935         37191638  milho

# %%
df_soja = df[df['tipo']=='soja']
df_soja.drop(['disponibilidade', 'tipo'], axis = 1,inplace=True)
df_soja.head(10)
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_18920\85193447.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_soja.drop(['disponibilidade', 'tipo'], axis = 1,inplace=True)
#     date   producao
# 0   2017  114732101
# 1   2018  117912450
# 2   2019  114316829
# 3   2020  121820949
# 4   2021  134799179
# 5   2022  139149400
# 12  2023  141351600
# 13  2024  143553700
# 14  2025  145755800
# 15  2026  147958000

# %%
df_milho = df[df['tipo']=='milho']
df_milho.drop(['disponibilidade', 'tipo'], axis = 1,inplace=True)
df_milho.head(10)
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_18920\3980232509.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_milho.drop(['disponibilidade', 'tipo'], axis = 1,inplace=True)
#     date   producao
# 6   2017   97910658
# 7   2018   82366531
# 8   2019  101126409
# 9   2020  103990935
# 10  2021   88272116
# 11  2022  101830605
# 20  2023  104695131
# 21  2024   88976312
# 22  2025  102534801
# 23  2026  105399327

# %%
# Definindo as variaveis com as colunas do df
x = df_soja['date']
y1 = df_alcool['liter']
y2 = df_soja['producao']
y3 = df_milho['producao']

# Cria uma nova Figura e Axes
fig, ax1 = plt.subplots()
 
# Cria um segundo Axes que compartilha o mesmo eixo x
ax2 = ax1.twinx()


 
# Plotar dados em cada Axes
ax1.plot(x, y1, 'k-', label='litro de etanol', marker='.', linestyle='dashed')
ax2.plot(x, y2, 'r-', label='soja', marker='.', linestyle='solid')   #marker='o'
ax2.plot(x, y3, 'b-', label='milho', marker='.', linestyle='dotted')   #marker='o'


# Definir rótulos dos eixos y
ax1.set_ylabel('Producação de litros de etanol (milhões de litros)', color='k', )
ax2.set_ylabel('Produção de grãos (toneladas)', color='r')
#ax1.set_ylabel('', color='b')

# Incluir legenda
ax1.legend(loc='center right')
ax2.legend(loc='upper left')


 
# Mostrar o gráfico
plt.show()
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_18920\237218541.py:16: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(x, y1, 'k-', label='litro de etanol', marker='.', linestyle='dashed')
# C:\Users\crist\AppData\Local\Temp\ipykernel_18920\237218541.py:17: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax2.plot(x, y2, 'r-', label='soja', marker='.', linestyle='solid')   #marker='o'
# C:\Users\crist\AppData\Local\Temp\ipykernel_18920\237218541.py:18: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax2.plot(x, y3, 'b-', label='milho', marker='.', linestyle='dotted')   #marker='o'

# %%
### Producao de graos e producao de proteina animal

# %%
#função para tratar campo data
def parser(x):
    return pd.datetime.strptime('190'+x, '%Y-%m')

#Agora vamos importar nosso arquivo 
df_alcool = pd.read_excel('../Grafico 5 - Proteina/db_br30.xlsx', sheet_name='Sheet1')
print(df_alcool.head(10))
# Out:
#    date   value    liter
# 0  2017  255.06   412770
# 1  2018  259.33   720236
# 2  2019  266.04  1330163
# 3  2020  267.16  2430153
# 4  2021  264.94  3296386
# 5  2022  291.40  4141401
# 6  2023  293.79  4986399
# 7  2024  296.65  5831395
# 8  2025  299.50  6676391
# 9  2026  302.35  7521387

# %%
df_alcool.drop(['liter'], axis = 1,inplace=True)

# %%
# Definindo as variaveis com as colunas do df
x = df_soja['date']
y1 = df_alcool['value']
y2 = df_soja['producao']
y3 = df_milho['producao']

# Cria uma nova Figura e Axes
fig, ax1 = plt.subplots()
 
# Cria um segundo Axes que compartilha o mesmo eixo x
ax2 = ax1.twinx()


 
# Plotar dados em cada Axes
ax1.plot(x, y1, 'k-', label='proteina', marker='.', linestyle='dashed')
ax2.plot(x, y2, 'r-', label='soja', marker='.', linestyle='solid')   #marker='o'
ax2.plot(x, y3, 'b-', label='milho', marker='.', linestyle='dotted')   #marker='o'



# Definir rótulos dos eixos y
ax1.set_ylabel('Producação de consumo de proteina animal (kg/capita/ano)' , color='k', )
ax2.set_ylabel('Produção de grãos (toneladas)', color='r')
#ax1.set_ylabel('', color='b')

# Incluir legenda
ax1.legend(loc='center right')
ax2.legend(loc='upper left')


# Mostrar o gráfico
plt.show()
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_18920\2093044288.py:16: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(x, y1, 'k-', label='proteina', marker='.', linestyle='dashed')
# C:\Users\crist\AppData\Local\Temp\ipykernel_18920\2093044288.py:17: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax2.plot(x, y2, 'r-', label='soja', marker='.', linestyle='solid')   #marker='o'
# C:\Users\crist\AppData\Local\Temp\ipykernel_18920\2093044288.py:18: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax2.plot(x, y3, 'b-', label='milho', marker='.', linestyle='dotted')   #marker='o'
